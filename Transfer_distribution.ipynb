# %%
from pymongo import MongoClient
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
import math
from tqdm import tqdm
from collections import Counter
# %matplotlib inline

# %%
client = MongoClient("localhost:27017")
database = client["golos_transactions"]
collection_transfer = database["transfer"]

# %% [markdown]
# # Constants

# %%
curators_coefficient = 0.25

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load topics from MongoDB

# %% [markdown]
# #### Find all comments with nonzero votes

# %%
comment_df = pd.DataFrame(list(collection_transfer.find({},
#     { type: 'GOLOS' },  
                                                       {
                                                        '_id': 1, 
                                                        'amount': 1, 
                                                        'blockid': 1, 
                                                        'from' : 1,
                                                        'memo' : 1,
                                                        'to' : 1,
                                                        'ts' : 1,
                                                        'type':1
                                                        }
                                                            )))

# %% [markdown]
# #### Count
#     -

# %%
comment_df.head()
# Out:
#                           _id      amount  blockid            from memo  \
# 0  286/cyberfounder/cyberdrop   4512000.0      286    cyberfounder
# 1      286/cyberfounder/golos   4051776.0      286    cyberfounder
# 2  287/cyberfounder/crowdsale  27072000.0      287    cyberfounder
# 3   1542/testzcrypto-11/testz         0.8     1542  testzcrypto-11
# 4           721/golos/golosio       500.0      721           golos
#
#           to                  ts   type
# 0  cyberdrop 2016-10-18 11:17:36  GOLOS
# 1      golos 2016-10-18 11:17:36  GOLOS
# 2  crowdsale 2016-10-18 11:17:42  GOLOS
# 3      testz 2016-10-18 12:22:06  GOLOS
# 4    golosio 2016-10-18 11:40:39  GOLOS

# %%
comment_df.shape
# Out:
# (7897563, 8)

# %%
comment_df.columns
# Out:
# Index(['_id', 'amount', 'blockid', 'from', 'memo', 'to', 'ts', 'type'], dtype='object')

# %%
unique_amount = comment_df.amount.unique()
print (unique_amount)

# for x in unique_amount[:10]:
#    print (x)

round_unique_amount = np.around(unique_amount,decimals=0)
print (round_unique_amount)

# for x in round_unique_amount[:10]:
#    print (x)

Counter(round_unique_amount)

# %%
Counter(round_unique_amount)
# Out:
# Counter({0.0: 500,
#          1.0: 999,
#          2.0: 1001,
#          3.0: 999,
#          4.0: 1001,
#          5.0: 999,
#          6.0: 1001,
#          7.0: 999,
#          8.0: 1000,
#          9.0: 995,
#          10.0: 991,
#          11.0: 969,
#          12.0: 967,
#          13.0: 953,
#          14.0: 936,
#          15.0: 929,
#          16.0: 890,
#          17.0: 874,
#          18.0: 835,
#          19.0: 797,
#          20.0: 769,
#          21.0: 747,
#          22.0: 707,
#          23.0: 686,
#          24.0: 669,
#          25.0: 671,
#          26.0: 650,
#          27.0: 618,
#          28.0: 631,
#          29.0: 619,
#          30.0: 625,
#          31.0: 567,
#          32.0: 555,
#          33.0: 549,
#          34.0: 508,
#          35.0: 556,
#          36.0: 491,
#          37.0: 526,
#          38.0: 463,
#          39.0: 441,
#          40.0: 415,
#          41.0: 402,
#          42.0: 419,
#          43.0: 409,
#          44.0: 402,
#          45.0: 388,
#          46.0: 347,
#          47.0: 343,
#          48.0: 334,
#          49.0: 353,
#          50.0: 369,
#          51.0: 331,
#          52.0: 349,
#          53.0: 325,
#          54.0: 338,
#          55.0: 281,
#          56.0: 291,
#          57.0: 283,
#          58.0: 271,
#          59.0: 317,
#          60.0: 312,
#          61.0: 274,
#          62.0: 249,
#          63.0: 270,
#          64.0: 235,
#          65.0: 247,
#          66.0: 237,
#          67.0: 243,
#          68.0: 226,
#          69.0: 211,
#          70.0: 216,
#          71.0: 238,
#          72.0: 229,
#          73.0: 185,
#          74.0: 212,
#          75.0: 188,
#          76.0: 190,
#          77.0: 230,
#          78.0: 215,
#          79.0: 201,
#          80.0: 200,
#          81.0: 226,
#          82.0: 190,
#          83.0: 189,
#          84.0: 186,
#          85.0: 179,
#          86.0: 183,
#          87.0: 177,
#          88.0: 168,
#          89.0: 170,
#          90.0: 172,
#          91.0: 169,
#          92.0: 164,
#          93.0: 172,
#          94.0: 165,
#          95.0: 195,
#          96.0: 170,
#          97.0: 179,
#          98.0: 150,
#          99.0: 176,
#          100.0: 213,
#          101.0: 203,
#          102.0: 164,
#          103.0: 163,
#          104.0: 155,
#          105.0: 146,
#          106.0: 157,
#          107.0: 167,
#          108.0: 170,
#          109.0: 160,
#          110.0: 153,
#          111.0: 148,
#          112.0: 165,
#          113.0: 141,
#          114.0: 131,
#          115.0: 146,
#          116.0: 143,
#          117.0: 160,
#          118.0: 129,
#          119.0: 133,
#          120.0: 132,
#          121.0: 129,
#          122.0: 147,
#          123.0: 139,
#          124.0: 124,
#          125.0: 122,
#          126.0: 144,
#          127.0: 154,
#          128.0: 136,
#          129.0: 120,
#          130.0: 122,
#          131.0: 118,
#          132.0: 113,
#          133.0: 125,
#          134.0: 121,
#          135.0: 100,
#          136.0: 102,
#          137.0: 105,
#          138.0: 108,
#          139.0: 105,
#          140.0: 127,
#          141.0: 117,
#          142.0: 113,
#          143.0: 113,
#          144.0: 89,
#          145.0: 108,
#          146.0: 97,
#          147.0: 98,
#          148.0: 89,
#          149.0: 79,
#          150.0: 129,
#          151.0: 101,
#          152.0: 103,
#          153.0: 80,
#          154.0: 95,
#          155.0: 96,
#          156.0: 77,
#          157.0: 73,
#          158.0: 100,
#          159.0: 83,
#          160.0: 92,
#          161.0: 104,
#          162.0: 96,
#          163.0: 83,
#          164.0: 74,
#          165.0: 80,
#          166.0: 103,
#          167.0: 84,
#          168.0: 87,
#          169.0: 90,
#          170.0: 94,
#          171.0: 93,
#          172.0: 79,
#          173.0: 78,
#          174.0: 79,
#          175.0: 72,
#          176.0: 81,
#          177.0: 82,
#          178.0: 94,
#          179.0: 81,
#          180.0: 78,
#          181.0: 82,
#          182.0: 69,
#          183.0: 71,
#          184.0: 73,
#          185.0: 72,
#          186.0: 65,
#          187.0: 73,
#          188.0: 63,
#          189.0: 62,
#          190.0: 63,
#          191.0: 55,
#          192.0: 68,
#          193.0: 73,
#          194.0: 63,
#          195.0: 70,
#          196.0: 89,
#          197.0: 69,
#          198.0: 55,
#          199.0: 61,
#          200.0: 118,
#          201.0: 103,
#          202.0: 77,
#          203.0: 87,
#          204.0: 81,
#          205.0: 65,
#          206.0: 64,
#          207.0: 66,
#          208.0: 60,
#          209.0: 55,
#          210.0: 75,
#          211.0: 67,
#          212.0: 57,
#          213.0: 79,
#          214.0: 69,
#          215.0: 58,
#          216.0: 69,
#          217.0: 58,
#          218.0: 51,
#          219.0: 62,
#          220.0: 74,
#          221.0: 64,
#          222.0: 75,
#          223.0: 47,
#          224.0: 56,
#          225.0: 64,
#          226.0: 67,
#          227.0: 76,
#          228.0: 66,
#          229.0: 61,
#          230.0: 66,
#          231.0: 54,
#          232.0: 66,
#          233.0: 58,
#          234.0: 50,
#          235.0: 60,
#          236.0: 70,
#          237.0: 49,
#          238.0: 50,
#          239.0: 66,
#          240.0: 59,
#          241.0: 63,
#          242.0: 61,
#          243.0: 53,
#          244.0: 51,
#          245.0: 47,
#          246.0: 45,
#          247.0: 54,
#          248.0: 72,
#          249.0: 58,
#          250.0: 66,
#          251.0: 56,
#          252.0: 63,
#          253.0: 59,
#          254.0: 60,
#          255.0: 68,
#          16640.0: 1,
#          257.0: 48,
#          258.0: 52,
#          259.0: 63,
#          260.0: 60,
#          261.0: 59,
#          262.0: 59,
#          263.0: 51,
#          264.0: 52,
#          265.0: 46,
#          266.0: 40,
#          267.0: 44,
#          268.0: 63,
#          269.0: 39,
#          270.0: 45,
#          271.0: 35,
#          272.0: 46,
#          273.0: 52,
#          274.0: 53,
#          275.0: 53,
#          276.0: 50,
#          277.0: 45,
#          278.0: 44,
#          279.0: 48,
#          280.0: 48,
#          281.0: 38,
#          282.0: 40,
#          283.0: 58,
#          284.0: 27,
#          285.0: 26,
#          286.0: 44,
#          287.0: 48,
#          288.0: 47,
#          289.0: 45,
#          290.0: 37,
#          291.0: 47,
#          292.0: 33,
#          293.0: 41,
#          294.0: 43,
#          295.0: 54,
#          296.0: 31,
#          297.0: 29,
#          298.0: 46,
#          299.0: 41,
#          300.0: 75,
#          301.0: 49,
#          302.0: 34,
#          303.0: 39,
#          304.0: 35,
#          305.0: 34,
#          306.0: 41,
#          307.0: 34,
#          308.0: 51,
#          309.0: 57,
#          310.0: 39,
#          311.0: 37,
#          312.0: 33,
#          313.0: 36,
#          314.0: 34,
#          315.0: 31,
#          316.0: 38,
#          317.0: 30,
#          318.0: 32,
#          319.0: 35,
#          320.0: 63,
#          321.0: 39,
#          322.0: 51,
#          323.0: 35,
#          324.0: 46,
#          325.0: 37,
#          326.0: 37,
#          327.0: 36,
#          328.0: 44,
#          329.0: 40,
#          330.0: 41,
#          331.0: 40,
#          332.0: 40,
#          333.0: 39,
#          334.0: 36,
#          335.0: 21,
#          336.0: 38,
#          337.0: 30,
#          338.0: 39,
#          339.0: 34,
#          340.0: 53,
#          341.0: 35,
#          342.0: 33,
#          343.0: 37,
#          344.0: 35,
#          345.0: 48,
#          346.0: 41,
#          347.0: 42,
#          348.0: 37,
#          349.0: 39,
#          350.0: 46,
#          351.0: 39,
#          352.0: 25,
#          353.0: 33,
#          354.0: 41,
#          355.0: 42,
#          356.0: 27,
#          357.0: 43,
#          358.0: 42,
#          359.0: 26,
#          360.0: 36,
#          361.0: 31,
#          362.0: 20,
#          363.0: 29,
#          364.0: 33,
#          365.0: 27,
#          366.0: 38,
#          367.0: 29,
#          368.0: 26,
#          369.0: 31,
#          370.0: 27,
#          371.0: 23,
#          372.0: 23,
#          373.0: 30,
#          374.0: 34,
#          375.0: 30,
#          376.0: 24,
#          377.0: 18,
#          378.0: 31,
#          379.0: 28,
#          380.0: 28,
#          381.0: 22,
#          382.0: 25,
#          383.0: 25,
#          384.0: 37,
#          385.0: 29,
#          386.0: 31,
#          387.0: 30,
#          388.0: 33,
#          389.0: 18,
#          390.0: 25,
#          391.0: 22,
#          392.0: 36,
#          393.0: 32,
#          394.0: 27,
#          395.0: 32,
#          396.0: 36,
#          397.0: 31,
#          398.0: 29,
#          399.0: 32,
#          400.0: 49,
#          401.0: 36,
#          402.0: 24,
#          403.0: 20,
#          404.0: 33,
#          405.0: 26,
#          406.0: 23,
#          407.0: 25,
#          408.0: 25,
#          409.0: 21,
#          410.0: 28,
#          411.0: 23,
#          412.0: 24,
#          413.0: 24,
#          414.0: 35,
#          415.0: 27,
#          416.0: 24,
#          417.0: 19,
#          418.0: 21,
#          419.0: 19,
#          420.0: 26,
#          421.0: 28,
#          422.0: 19,
#          423.0: 35,
#          424.0: 26,
#          425.0: 20,
#          426.0: 24,
#          427.0: 24,
#          428.0: 22,
#          429.0: 20,
#          430.0: 25,
#          431.0: 27,
#          432.0: 29,
#          433.0: 26,
#          434.0: 20,
#          435.0: 20,
#          436.0: 29,
#          437.0: 18,
#          438.0: 18,
#          439.0: 19,
#          440.0: 33,
#          441.0: 21,
#          442.0: 23,
#          443.0: 15,
#          444.0: 20,
#          445.0: 34,
#          446.0: 19,
#          447.0: 18,
#          448.0: 18,
#          449.0: 29,
#          450.0: 30,
#          451.0: 20,
#          452.0: 19,
#          453.0: 23,
#          454.0: 27,
#          455.0: 28,
#          456.0: 25,
#          457.0: 21,
#          458.0: 19,
#          459.0: 13,
#          460.0: 31,
#          461.0: 37,
#          462.0: 40,
#          463.0: 19,
#          464.0: 15,
#          465.0: 19,
#          466.0: 14,
#          467.0: 18,
#          468.0: 20,
#          469.0: 19,
#          470.0: 20,
#          471.0: 19,
#          472.0: 17,
#          473.0: 11,
#          474.0: 20,
#          475.0: 19,
#          476.0: 21,
#          477.0: 21,
#          478.0: 18,
#          479.0: 24,
#          480.0: 19,
#          481.0: 18,
#          482.0: 18,
#          483.0: 21,
#          484.0: 19,
#          485.0: 17,
#          486.0: 20,
#          487.0: 24,
#          488.0: 20,
#          489.0: 20,
#          490.0: 17,
#          491.0: 17,
#          492.0: 14,
#          493.0: 23,
#          494.0: 22,
#          495.0: 16,
#          496.0: 13,
#          497.0: 21,
#          498.0: 22,
#          499.0: 25,
#          500.0: 51,
#          501.0: 39,
#          502.0: 15,
#          503.0: 24,
#          504.0: 17,
#          505.0: 14,
#          506.0: 23,
#          507.0: 10,
#          508.0: 23,
#          509.0: 26,
#          510.0: 20,
#          511.0: 19,
#          512.0: 13,
#          513.0: 21,
#          514.0: 17,
#          515.0: 18,
#          516.0: 18,
#          517.0: 22,
#          518.0: 22,
#          519.0: 18,
#          520.0: 26,
#          521.0: 14,
#          522.0: 17,
#          523.0: 13,
#          524.0: 19,
#          525.0: 20,
#          526.0: 18,
#          527.0: 21,
#          528.0: 20,
#          529.0: 18,
#          530.0: 19,
#          531.0: 18,
#          532.0: 19,
#          533.0: 13,
#          534.0: 21,
#          535.0: 13,
#          536.0: 18,
#          537.0: 17,
#          538.0: 18,
#          539.0: 12,
#          540.0: 21,
#          541.0: 13,
#          542.0: 11,
#          543.0: 13,
#          544.0: 13,
#          545.0: 13,
#          546.0: 19,
#          547.0: 17,
#          548.0: 22,
#          549.0: 11,
#          550.0: 28,
#          551.0: 24,
#          552.0: 17,
#          553.0: 12,
#          554.0: 16,
#          555.0: 22,
#          556.0: 12,
#          557.0: 18,
#          558.0: 12,
#          559.0: 10,
#          560.0: 12,
#          561.0: 12,
#          562.0: 10,
#          563.0: 16,
#          564.0: 18,
#          565.0: 11,
#          566.0: 13,
#          567.0: 10,
#          568.0: 17,
#          569.0: 17,
#          570.0: 14,
#          571.0: 16,
#          572.0: 15,
#          573.0: 12,
#          574.0: 9,
#          575.0: 14,
#          576.0: 16,
#          577.0: 12,
#          578.0: 21,
#          579.0: 13,
#          580.0: 15,
#          581.0: 16,
#          582.0: 19,
#          583.0: 20,
#          584.0: 17,
#          585.0: 12,
#          586.0: 10,
#          587.0: 8,
#          588.0: 20,
#          589.0: 16,
#          590.0: 17,
#          591.0: 8,
#          592.0: 16,
#          593.0: 18,
#          594.0: 10,
#          595.0: 18,
#          596.0: 11,
#          597.0: 13,
#          598.0: 11,
#          599.0: 20,
#          600.0: 25,
#          601.0: 17,
#          602.0: 12,
#          603.0: 12,
#          604.0: 10,
#          605.0: 17,
#          606.0: 14,
#          607.0: 18,
#          608.0: 10,
#          609.0: 12,
#          610.0: 13,
#          611.0: 18,
#          612.0: 11,
#          613.0: 17,
#          614.0: 13,
#          615.0: 12,
#          616.0: 16,
#          617.0: 8,
#          618.0: 14,
#          619.0: 12,
#          620.0: 15,
#          621.0: 26,
#          622.0: 12,
#          623.0: 12,
#          624.0: 16,
#          625.0: 11,
#          626.0: 15,
#          627.0: 11,
#          628.0: 10,
#          629.0: 14,
#          630.0: 16,
#          631.0: 19,
#          632.0: 13,
#          633.0: 14,
#          634.0: 9,
#          635.0: 8,
#          636.0: 13,
#          637.0: 12,
#          638.0: 9,
#          639.0: 10,
#          640.0: 18,
#          641.0: 13,
#          642.0: 10,
#          643.0: 13,
#          644.0: 10,
#          645.0: 12,
#          646.0: 7,
#          647.0: 12,
#          648.0: 11,
#          649.0: 7,
#          650.0: 10,
#          651.0: 15,
#          652.0: 9,
#          653.0: 15,
#          654.0: 8,
#          655.0: 9,
#          656.0: 14,
#          657.0: 12,
#          658.0: 22,
#          659.0: 11,
#          660.0: 17,
#          16494.0: 1,
#          662.0: 12,
#          663.0: 16,
#          664.0: 11,
#          665.0: 11,
#          666.0: 12,
#          667.0: 11,
#          668.0: 10,
#          669.0: 7,
#          670.0: 11,
#          671.0: 15,
#          672.0: 14,
#          673.0: 6,
#          674.0: 11,
#          675.0: 7,
#          676.0: 16,
#          677.0: 10,
#          678.0: 11,
#          679.0: 15,
#          680.0: 14,
#          681.0: 7,
#          682.0: 9,
#          683.0: 16,
#          684.0: 12,
#          685.0: 12,
#          686.0: 6,
#          687.0: 13,
#          688.0: 9,
#          689.0: 14,
#          690.0: 15,
#          691.0: 12,
#          692.0: 14,
#          693.0: 9,
#          694.0: 6,
#          695.0: 7,
#          696.0: 12,
#          697.0: 9,
#          698.0: 8,
#          699.0: 11,
#          700.0: 22,
#          701.0: 11,
#          702.0: 13,
#          703.0: 11,
#          704.0: 12,
#          705.0: 11,
#          706.0: 12,
#          707.0: 13,
#          708.0: 8,
#          709.0: 15,
#          710.0: 8,
#          711.0: 10,
#          712.0: 14,
#          713.0: 12,
#          714.0: 13,
#          715.0: 12,
#          716.0: 11,
#          717.0: 8,
#          718.0: 8,
#          719.0: 8,
#          720.0: 11,
#          721.0: 10,
#          722.0: 10,
#          723.0: 15,
#          724.0: 15,
#          725.0: 15,
#          726.0: 15,
#          727.0: 15,
#          728.0: 11,
#          729.0: 7,
#          730.0: 15,
#          731.0: 12,
#          732.0: 12,
#          733.0: 16,
#          734.0: 17,
#          735.0: 14,
#          736.0: 9,
#          737.0: 12,
#          738.0: 15,
#          739.0: 13,
#          740.0: 9,
#          741.0: 9,
#          742.0: 9,
#          743.0: 13,
#          744.0: 18,
#          745.0: 8,
#          17130.0: 1,
#          747.0: 14,
#          748.0: 9,
#          749.0: 12,
#          750.0: 19,
#          751.0: 11,
#          752.0: 6,
#          753.0: 8,
#          754.0: 9,
#          755.0: 10,
#          756.0: 10,
#          757.0: 12,
#          758.0: 8,
#          759.0: 7,
#          760.0: 10,
#          761.0: 9,
#          762.0: 10,
#          763.0: 11,
#          764.0: 5,
#          765.0: 9,
#          766.0: 9,
#          767.0: 12,
#          768.0: 7,
#          769.0: 3,
#          770.0: 15,
#          771.0: 7,
#          772.0: 6,
#          773.0: 9,
#          774.0: 14,
#          775.0: 13,
#          776.0: 11,
#          777.0: 11,
#          778.0: 16,
#          779.0: 9,
#          780.0: 13,
#          781.0: 9,
#          782.0: 11,
#          783.0: 9,
#          784.0: 10,
#          785.0: 12,
#          786.0: 8,
#          787.0: 10,
#          788.0: 12,
#          789.0: 8,
#          790.0: 5,
#          791.0: 17,
#          792.0: 11,
#          793.0: 6,
#          794.0: 4,
#          795.0: 10,
#          796.0: 7,
#          797.0: 10,
#          798.0: 7,
#          799.0: 5,
#          800.0: 21,
#          801.0: 13,
#          802.0: 12,
#          803.0: 20,
#          804.0: 9,
#          805.0: 14,
#          806.0: 8,
#          807.0: 14,
#          808.0: 8,
#          809.0: 10,
#          810.0: 12,
#          811.0: 8,
#          812.0: 20,
#          813.0: 13,
#          814.0: 9,
#          815.0: 6,
#          816.0: 13,
#          817.0: 9,
#          818.0: 8,
#          819.0: 7,
#          820.0: 9,
#          821.0: 9,
#          822.0: 9,
#          823.0: 10,
#          824.0: 11,
#          825.0: 11,
#          826.0: 17,
#          827.0: 10,
#          828.0: 8,
#          829.0: 9,
#          830.0: 7,
#          831.0: 13,
#          832.0: 10,
#          833.0: 8,
#          834.0: 6,
#          835.0: 4,
#          836.0: 11,
#          837.0: 13,
#          838.0: 6,
#          839.0: 5,
#          840.0: 13,
#          841.0: 6,
#          842.0: 6,
#          843.0: 12,
#          844.0: 8,
#          845.0: 8,
#          846.0: 8,
#          847.0: 10,
#          848.0: 7,
#          849.0: 9,
#          850.0: 11,
#          851.0: 10,
#          852.0: 11,
#          853.0: 7,
#          854.0: 12,
#          855.0: 14,
#          856.0: 12,
#          857.0: 14,
#          858.0: 7,
#          859.0: 9,
#          860.0: 13,
#          861.0: 9,
#          862.0: 8,
#          863.0: 8,
#          864.0: 13,
#          865.0: 10,
#          866.0: 7,
#          867.0: 7,
#          868.0: 7,
#          869.0: 9,
#          870.0: 11,
#          871.0: 6,
#          872.0: 6,
#          873.0: 10,
#          874.0: 4,
#          875.0: 9,
#          876.0: 6,
#          877.0: 7,
#          878.0: 4,
#          879.0: 14,
#          880.0: 11,
#          881.0: 5,
#          882.0: 5,
#          883.0: 8,
#          884.0: 17,
#          885.0: 4,
#          886.0: 6,
#          887.0: 9,
#          888.0: 7,
#          889.0: 14,
#          890.0: 12,
#          891.0: 4,
#          892.0: 11,
#          893.0: 12,
#          894.0: 10,
#          895.0: 10,
#          896.0: 3,
#          897.0: 6,
#          898.0: 8,
#          899.0: 7,
#          900.0: 11,
#          901.0: 11,
#          902.0: 4,
#          903.0: 7,
#          904.0: 4,
#          905.0: 6,
#          906.0: 12,
#          907.0: 10,
#          908.0: 7,
#          909.0: 8,
#          910.0: 9,
#          911.0: 7,
#          912.0: 6,
#          913.0: 10,
#          914.0: 4,
#          915.0: 11,
#          916.0: 11,
#          917.0: 9,
#          918.0: 4,
#          919.0: 8,
#          920.0: 9,
#          921.0: 9,
#          922.0: 8,
#          923.0: 9,
#          924.0: 6,
#          925.0: 8,
#          926.0: 6,
#          927.0: 8,
#          928.0: 8,
#          929.0: 14,
#          930.0: 13,
#          931.0: 14,
#          932.0: 9,
#          933.0: 6,
#          934.0: 6,
#          935.0: 4,
#          936.0: 7,
#          937.0: 10,
#          938.0: 12,
#          939.0: 9,
#          940.0: 9,
#          941.0: 9,
#          942.0: 5,
#          943.0: 9,
#          944.0: 4,
#          945.0: 6,
#          946.0: 6,
#          947.0: 5,
#          948.0: 6,
#          949.0: 6,
#          950.0: 8,
#          951.0: 7,
#          952.0: 11,
#          953.0: 9,
#          954.0: 6,
#          955.0: 6,
#          956.0: 7,
#          957.0: 9,
#          958.0: 14,
#          959.0: 8,
#          960.0: 9,
#          961.0: 2,
#          962.0: 12,
#          963.0: 10,
#          964.0: 10,
#          965.0: 7,
#          17350.0: 1,
#          967.0: 6,
#          968.0: 5,
#          969.0: 9,
#          970.0: 13,
#          971.0: 9,
#          972.0: 6,
#          973.0: 6,
#          974.0: 6,
#          975.0: 8,
#          976.0: 4,
#          977.0: 7,
#          978.0: 5,
#          979.0: 4,
#          980.0: 7,
#          981.0: 5,
#          982.0: 7,
#          983.0: 9,
#          984.0: 9,
#          985.0: 6,
#          986.0: 7,
#          987.0: 6,
#          988.0: 9,
#          989.0: 11,
#          990.0: 8,
#          991.0: 10,
#          992.0: 6,
#          993.0: 5,
#          994.0: 7,
#          995.0: 9,
#          996.0: 11,
#          997.0: 9,
#          998.0: 10,
#          999.0: 10,
#          ...})

# %%
labels, values = zip(*Counter(round_unique_amount).items())

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
plt.show()

# %%
labels, values = zip(*Counter(round_unique_amount).items())

indexes = np.arange(len(labels))
#width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)




mpl.rcParams['figure.figsize'] = (18.0, 9.0)
plt.rcParams.update({'font.size': 16})

plt.title("Paid amount transaction distriubtion")


plt.show()

# %%
comment_df['amount']
# Out:
# 0          4.512000e+06
# 1          4.051776e+06
# 2          2.707200e+07
# 3          8.000000e-01
# 4          5.000000e+02
# 5          2.000000e+00
# 6          5.000000e+03
# 7          5.000000e+01
# 8          1.000000e+02
# 9          8.000000e-01
# 10         7.900000e-01
# 11         6.500000e-01
# 12         7.900000e-01
# 13         6.500000e-01
# 14         1.000000e-01
# 15         9.000000e-01
# 16         1.000000e-02
# 17         3.090000e-01
# 18         1.000000e-03
# 19         1.000000e-01
# 20         1.000000e-03
# 21         1.000000e-03
# 22         1.000000e-03
# 23         1.000000e-03
# 24         1.000000e-03
# 25         1.000000e-03
# 26         1.000000e-03
# 27         1.000000e-03
# 28         1.000000e-03
# 29         1.000000e-03
#                ...
# 7897958    1.000000e-03
# 7897959    5.000000e-03
# 7897960    1.000000e-03
# 7897961    1.000000e-03
# 7897962    1.000000e-03
# 7897963    1.000000e-03
# 7897964    1.000000e-03
# 7897965    1.000000e-03
# 7897966    1.000000e-03
# 7897967    5.000000e-03
# 7897968    1.000000e-03
# 7897969    1.000000e-03
# 7897970    1.000000e-03
# 7897971    1.000000e-03
# 7897972    1.000000e-03
# 7897973    1.000000e-03
# 7897974    1.000000e-03
# 7897975    1.000000e-03
# 7897976    1.000000e-03
# 7897977    1.000000e-03
# 7897978    1.000000e-03
# 7897979    5.000000e-03
# 7897980    1.000000e-03
# 7897981    1.000000e-03
# 7897982    1.000000e-03
# 7897983    1.000000e-03
# 7897984    1.000000e-03
# 7897985    1.000000e-03
# 7897986    1.000000e-03
# 7897987    1.000000e-03
# Name: amount, Length: 7897988, dtype: float64

# %%
plt.hist(comment_df['amount'], range=(10, 3000), bins=500)
plt.show()

# %% [markdown]
# #### X - golos_transactions.Amount, Y - Frequency of occurences

# %%
unique_from = comment_df.from.unique()
print (unique_from)
# Out:
#   File "<ipython-input-121-7884fc9e0e29>", line 1
#     unique_from = comment_df.from.unique()
#                                 ^
# SyntaxError: invalid syntax

# %%
Counter(unique_from)

# %%
comment_df['last_payout'] = comment_df['last_payout'].map(lambda x: x if x==x else datetime(2000,1,1))
comment_df['last_payout_date'] = comment_df['last_payout'].map(lambda x: x.date())
comment_df.loc[:,'delta_payout_time'] = comment_df.apply(lambda x: x['last_payout'] - x['created'], axis=1)

# %%
comment_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Save weights of each vote from the 1st till the 3rd of February

# %%
comment_votes_df = comment_df[(comment_df['created']>datetime(2018,2,1)) & \
                              (comment_df['created']<datetime(2018,2,9,9)) & \
                              (comment_df['curator_payout_value']>0)]
new_df_list = []
for i in tqdm(comment_votes_df.index):
    row = comment_votes_df.loc[i,:]
    sum_weight = 0
    for item in row['active_votes']:
        sum_weight+=item['weight']
    if sum_weight>0:
        for item in row['active_votes']:
            new_df_list.append([row['_id'], row['author'], row['created'], row['last_payout'],  item['voter'], item['weight']/sum_weight])
curators_df = pd.DataFrame(data=new_df_list, columns=['_id', 'author', 'created', 'last_payout', 'voter', 'weight'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'curator_payout_value'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-d2c350ed5b7d> in <module>()
# ----> 1 comment_votes_df = comment_df[(comment_df['created']>datetime(2018,2,1)) &                               (comment_df['created']<datetime(2018,2,9,9)) &                               (comment_df['curator_payout_value']>0)]
#       2 new_df_list = []
#       3 for i in tqdm(comment_votes_df.index):
#       4     row = comment_votes_df.loc[i,:]
#       5     sum_weight = 0
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'curator_payout_value'

# %% [markdown]
# #### Add info about payouts calculated with alternative functions

# %%
alternative_comment_df = pd.read_csv("comments_with_alternative_rshares.csv")

# %%
alternative_comment_df = alternative_comment_df[['author', 
                                                 'created', 
                                                 'permlink', 
                                                 'depth', 
                                                 'payout_rshares2',
                                                 'payout_rshares_linear', 
                                                 'payout_rshares15', 
                                                 'payout_rshares2_2',
                                                 'payout_rshares_compose']]

# %%
alternative_comment_df["_id"] = alternative_comment_df["author"] + "/" + alternative_comment_df["permlink"]

# %% [markdown]
# #### Add info about categories of curators

# %%
authors_df = pd.read_csv("all_cat.csv")

# %%
independent_authors_df = pd.read_csv('independent_authors.csv')

# %% [markdown]
# #### Split two DataFrames

# %%
authors_df = authors_df.append(independent_authors_df['author'].reset_index())
authors_df.cat = authors_df.cat.fillna("Независимые авторы")
authors_df.total_payout_value = authors_df.total_payout_value.fillna(0)

# %% [markdown]
# #### Tranform to DataFrame with unique authors

# %%
authors_df = authors_df.groupby(["cat", "author"])["total_payout_value"].sum().reset_index()
authors_df = authors_df.groupby(["author"]).\
                            apply(lambda g: g[g.total_payout_value == g.total_payout_value.max()])\
                                                                        [['cat']].reset_index()[["cat", "author"]]
authors_df = authors_df.groupby(["author"])["cat"].min().reset_index()

# %% [markdown]
# #### Merge voters and accounts role

# %%
rewards_with_curators = pd.merge(curators_df, 
                                 authors_df, 
                                 left_on="voter", 
                                 right_on="author", 
                                 how="left")

# %%
rewards_with_curators.cat = rewards_with_curators.cat.fillna("Прочие пользователи")

# %% [markdown]
# #### Merge curation rewards and voter role

# %% [markdown]
# #### Merge curation rewards and voter role

# %%
rewards_with_curators_and_coefficients = pd.merge(rewards_with_curators[["_id", 
                                                                         "voter", 
                                                                         "weight", 
                                                                         "cat"]], 
                                                  alternative_comment_df[["_id", 
                                                                          "payout_rshares2", 
                                                                          "payout_rshares_linear", 
                                                                          "payout_rshares15", 
                                                                          "payout_rshares2_2", 
                                                                          "payout_rshares_compose"]], 
                                                  left_on="_id", 
                                                  right_on="_id", 
                                                  how="inner")

# %%
rewards_with_curators_and_coefficients["cat"] = rewards_with_curators_and_coefficients["cat"].fillna("Прочие")

# %% [markdown]
# #### Count payout for each curator according the weight of his vote

# %%
for f in ['rshares2', 
          'rshares_linear', 
          'rshares15', 
          'rshares2_2', 
          "rshares_compose"]:
    rewards_with_curators_and_coefficients['curator_payout_' + f] = round(rewards_with_curators_and_coefficients['payout_' + f] * curators_coefficient * rewards_with_curators_and_coefficients['weight'],3)

# %% [markdown]
# #### Find a distribution of rewards calculated with different rshares functions by curator groups

# %%
rewards_with_curators_and_coefficients.cat = rewards_with_curators_and_coefficients.cat.map(lambda x: 'Авторы '+x if x in ('PSK','Vox Populi', 'Апвот 50-50') else x)

# %%
stacked_df = rewards_with_curators_and_coefficients.fillna(0).groupby("cat")[['curator_payout_' + x for x in ['rshares2', 'rshares_linear', 'rshares15', 'rshares2_2', "rshares_compose"]]].sum()

# %%
mpl.rcParams['figure.figsize'] = (18.0, 9.0)
plt.rcParams.update({'font.size': 16})
plot = (stacked_df / stacked_df.sum()).T.plot(kind='bar', stacked=True, figsize=(15, 10))
plt.title("Распределение вознаграждений по группам кураторов при различных функциях")
plt.legend(title="Группа")
plot.set_xticklabels(["Квадратичная",  
                      "Квадратичная, где s=2e+13",
                      "Полином степени 1.5",                       
                      "Линейная", 
                      "Линейно-логарифмическая"])
plt.show()
